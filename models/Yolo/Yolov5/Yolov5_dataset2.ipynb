# %% [markdown]
# <a href="https://colab.research.google.com/github/ANACERMIR/Capstone_Project_G13/blob/main/models/Yolo/Yolov5/Yolov5_dataset2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Navantia_banner.png](data:image/png;base64,...)

# %% [markdown]
# # **Yolo V5 Navantia Object Detection-- Dataset v2-- Capstone Project**

# %% [markdown]
# ## **Set Up**

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd /content/yolov5
# !pip install -r requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15274, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 15274 (delta 11), reused 24 (delta 6), pack-reused 15236
# Receiving objects: 100% (15274/15274), 14.23 MiB | 8.29 MiB/s, done.
# Resolving deltas: 100% (10465/10465), done.
# /content/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 9.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ...

# %% [markdown]
# ## **Dataset v2 input**

# %%
# %cd /content/yolov5
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="Ny3g4ZIR8JLlIGGc8uX6")
project = rf.workspace("capstone-project-ie").project("capstone-nv")
dataset = project.version(9).download("yolov5")
# Out:
# /content/yolov5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 KB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 20.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 8.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=c00c90643d8c88c33d38c6c2745031f4a905f6486ac824a9d84f76adb8464ae6
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyparsing
# ...

# %% [markdown]
# ## **Model Training**

# %%
# !python train.py --batch 16 --epochs 25 --data /content/yolov5/Capstone-NV-9/data.yaml --weights yolov5l.pt --cache
# Out:
# train: weights=yolov5l.pt, cfg=, data=/content/yolov5/Capstone-NV-9/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# ## **Inference with Model**

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --conf 0.1 --source /content/yolov5/Capstone-NV-9/test/images
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/yolov5/Capstone-NV-9/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46135203 parameters, 0 gradients, 107.7 GFLOPs
# image 1/843 /content/yolov5/Capstone-NV-9/test/images/00000013_jpg.rf.5317052ff6c0b4399ae1710ec1222f0c.jpg: 640x640 1 helicopter, 52.5ms
# image 2/843 /content/yolov5/Capstone-NV-9/test/images/00000030_jpg.rf.3f9375ddbc095968230aa951f0696ee9.jpg: 640x640 1 helicopter, 52.6ms
# ...

# %% [markdown]
# ## **Save Model**

# %%
# Way around to avoid error when saving results
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# Save results
# Write your experience name
from google.colab import files
# !zip -r results.zip /content/yolov5/runs/train/exp2
files.download("results.zip")
# Out:
#   adding: content/yolov5/runs/train/exp2/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/confusion_matrix.png (deflated 24%)
#   adding: content/yolov5/runs/train/exp2/F1_curve.png (deflated 12%)
#   adding: content/yolov5/runs/train/exp2/val_batch0_labels.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/exp2/results.png (deflated 11%)
#   adding: content/yolov5/runs/train/exp2/opt.yaml (deflated 48%)
#   adding: content/yolov5/runs/train/exp2/R_curve.png (deflated 13%)
#   adding: content/yolov5/runs/train/exp2/train_batch1.jpg (deflated 6%)
#   adding: content/yolov5/runs/train/exp2/val_batch0_pred.jpg (deflated 6%)
#   adding: content/yolov5/runs/train/exp2/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/weights/best.pt (deflated 8%)
#   adding: content/yolov5/runs/train/exp2/weights/last.pt (deflated 8%)
#   adding: content/yolov5/runs/train/exp2/train_batch0.jpg (deflated 5%)
# ...
